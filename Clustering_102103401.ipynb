# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %%
from pycaret.utils import version
version()
# Out:
# '3.2.0'

# %%
from pycaret.datasets import get_data
dataSets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
iris_dataset = get_data('iris')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris_dataset.to_csv("iris_dataset.csv")
from google.colab import files

# %%
files.download('iris_dataset.csv')

# %% [markdown]
# **kMeans Clustering**

# %%
from pycaret.clustering import *
kMeanClusteringParameters = setup(iris_dataset)
# Out:
# <style type="text/css">
# #T_d3cba_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d3cba" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3cba_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d3cba_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3cba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d3cba_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d3cba_row0_col1" class="data row0 col1" >7435</td>
#     </tr>
#     <tr>
#       <th id="T_d3cba_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d3cba_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_d3cba_row1_col1" class="data row1 col1" >(150, 5)</td>
#     </tr>
#     <tr>
# ...

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6e844" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e844_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6e844_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6e844_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6e844_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6e844_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6e844_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e844_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e844_row0_col0" class="data row0 col0" >0.5785</td>
#       <td id="T_6e844_row0_col1" class="data row0 col1" >514.0075</td>
# ...

# %%
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#        Cluster
# 0    Cluster 0
# 1    Cluster 0
# 2    Cluster 0
# ...

# %%
kMeanPrediction.to_csv("KMeanResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
from google.colab import files
files.download('KMeanResult.csv')      # Uncomment this line
# Open and Explore result file (KMeanResult.csv).

# %%
x = save_model(KMeanClusteringModel, 'kMeanClusteringModelFile')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %%
from google.colab import files
# files.download('kMeanClusteringModelFile.pkl')

# %% [markdown]
# **CLUSTERING**

# %%
newData = get_data("iris").iloc[:10]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
newPredictions = predict_model(KMeanClusteringModel, data = newData)
newPredictions
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species_Iris-setosa  \
# 0           5.1          3.5           1.4          0.2                  1.0
# 1           4.9          3.0           1.4          0.2                  1.0
# 2           4.7          3.2           1.3          0.2                  1.0
# 3           4.6          3.1           1.5          0.2                  1.0
# 4           5.0          3.6           1.4          0.2                  1.0
# 5           5.4          3.9           1.7          0.4                  1.0
# 6           4.6          3.4           1.4          0.3                  1.0
# 7           5.0          3.4           1.5          0.2                  1.0
# 8           4.4          2.9           1.4          0.2                  1.0
# 9           4.9          3.1           1.5          0.1                  1.0
#
#    species_Iris-versicolor  species_Iris-virginica    Cluster
# ...

# %% [markdown]
# **Evaluating Cluster Model**

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# 2D plot
plot_model(KMeanClusteringModel, plot='cluster')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#3D plot
plot_model(KMeanClusteringModel, plot = 'tsne')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Elbow Plot
plot_model(KMeanClusteringModel, plot = 'elbow')

# %%
#Silhouette Plot
plot_model(KMeanClusteringModel, plot = 'silhouette')

# %%
# Distribution Plot
plot_model(KMeanClusteringModel, plot = 'distribution')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Clustering (KMean)**

# %%
# For Cluster = 3, 4, 5, 6
from pycaret.datasets import get_data
from pycaret.clustering import *

iris_dataset = get_data('iris', verbose=False)
setup(data = iris_dataset, verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_5c730" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c730_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5c730_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5c730_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5c730_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5c730_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5c730_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c730_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5c730_row0_col0" class="data row0 col0" >0.6223</td>
#       <td id="T_5c730_row0_col1" class="data row0 col1" >576.5206</td>
# ...

# %%
import pandas as pd

# Create an empty list to store model summaries
model_summaries = []

# Iterate through different cluster numbers
for num_clusters in [3, 4, 5, 6]:
    print(f"For Cluster = {num_clusters}")

    # Create the KMeans model
    model = create_model('kmeans', num_clusters=num_clusters)

    # Get the model summary as a DataFrame
    model_summary = pull()

    # Create a new DataFrame with Cluster Number as the first column
    model_summary.insert(0, "Cluster Number", num_clusters)

    # Append the model summary to the list
    model_summaries.append(model_summary)

# Concatenate all model summaries into a single table
combined_table = pd.concat(model_summaries)

# Display the combined table
print(combined_table)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_37444" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37444_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_37444_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_37444_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_37444_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_37444_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_37444_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37444_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_37444_row0_col0" class="data row0 col0" >0.6223</td>
#       <td id="T_37444_row0_col1" class="data row0 col1" >576.5206</td>
# ...

# %% [markdown]
# # ***Clustering: "Data Preprocessing"***

# %%
from pycaret.clustering import *
from pycaret.datasets import get_data

iris_dataset = get_data('iris')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# **Model Performance using "Normalization"**

# %%
#Model Performance using "Normalization"
#Elbow Plot
setup(data = iris_dataset, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')

#Evaluation parameters for Cluster = 3, 4, 5, 6
setup(data = iris_dataset, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2de18" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2de18_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2de18_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2de18_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2de18_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2de18_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2de18_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2de18_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2de18_row0_col0" class="data row0 col0" >0.5699</td>
#       <td id="T_2de18_row0_col1" class="data row0 col1" >321.2588</td>
# ...

# %%
#3D Plot for Cluster = 5
setup(data = iris_dataset, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('kmeans', num_clusters = 5)
plot_model(x, plot = 'tsne')
# Out:
# <style type="text/css">
# </style>
# <table id="T_f27b2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f27b2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f27b2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f27b2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f27b2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f27b2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f27b2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f27b2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f27b2_row0_col0" class="data row0 col0" >0.4705</td>
#       <td id="T_f27b2_row0_col1" class="data row0 col1" >304.9351</td>
# ...

# %% [markdown]
# # Model Performance using "Transformation"

# %%
# Model Performance using "Transformation"
#Elbow Plot
setup(data = iris_dataset, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_e80fa" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e80fa_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e80fa_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e80fa_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e80fa_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e80fa_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e80fa_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e80fa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e80fa_row0_col0" class="data row0 col0" >0.6033</td>
#       <td id="T_e80fa_row0_col1" class="data row0 col1" >1274.7031</td>
# ...

# %%
# Evaluation parameters for Cluster = 3, 4, 5, 6
setup(data = iris_dataset, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_c4040" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4040_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c4040_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c4040_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c4040_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c4040_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c4040_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4040_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c4040_row0_col0" class="data row0 col0" >0.6600</td>
#       <td id="T_c4040_row0_col1" class="data row0 col1" >1153.7177</td>
# ...

# %% [markdown]
# # Model Performance using "PCA"

# %%
#Elbow Plot
setup(data = iris_dataset, pca = True, pca_method = 'linear', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_53f48" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53f48_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_53f48_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_53f48_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_53f48_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_53f48_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_53f48_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53f48_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_53f48_row0_col0" class="data row0 col0" >0.5785</td>
#       <td id="T_53f48_row0_col1" class="data row0 col1" >514.0075</td>
# ...

# %%
#Evaluation parameters for Cluster = 3, 4, 5, 6
setup(data = iris_dataset, pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_87a0b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87a0b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_87a0b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_87a0b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_87a0b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_87a0b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_87a0b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87a0b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87a0b_row0_col0" class="data row0 col0" >0.6223</td>
#       <td id="T_87a0b_row0_col1" class="data row0 col1" >576.5206</td>
# ...

# %% [markdown]
# # Model Performance using "Transformation" + "Normalization"

# %%
#Model Performance using "Transformation" + "Normalization"
#Elbow Plot
setup(data = iris_dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_2a272" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a272_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2a272_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2a272_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2a272_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2a272_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2a272_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a272_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2a272_row0_col0" class="data row0 col0" >0.5787</td>
#       <td id="T_2a272_row0_col1" class="data row0 col1" >327.1575</td>
# ...

# %%
setup(data = iris_dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_a5b87" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5b87_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a5b87_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a5b87_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a5b87_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a5b87_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a5b87_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5b87_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5b87_row0_col0" class="data row0 col0" >0.6577</td>
#       <td id="T_a5b87_row0_col1" class="data row0 col1" >391.8238</td>
# ...

# %% [markdown]
# # Model Performance using "Transformation" + "Normalization" + "PCA"

# %%
# Model Performance using "Transformation" + "Normalization" + "PCA"
#Elbow Plot
setup(data = iris_dataset, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_4923a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4923a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4923a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4923a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4923a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4923a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4923a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4923a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4923a_row0_col0" class="data row0 col0" >0.5787</td>
#       <td id="T_4923a_row0_col1" class="data row0 col1" >327.1575</td>
# ...

# %%
setup(data = iris_dataset, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore',
      transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_4b423" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b423_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4b423_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4b423_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4b423_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4b423_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4b423_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b423_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4b423_row0_col0" class="data row0 col0" >0.6577</td>
#       <td id="T_4b423_row0_col1" class="data row0 col1" >391.8238</td>
# ...

# %% [markdown]
# # Other Clustering Techniques

# %% [markdown]
# **Hierarchical**

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

iris_dataset = get_data('iris', verbose=False)
setup(data = iris_dataset, verbose=False)

x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_9b7d3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b7d3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9b7d3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9b7d3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9b7d3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9b7d3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9b7d3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b7d3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9b7d3_row0_col0" class="data row0 col0" >0.5865</td>
#       <td id="T_9b7d3_row0_col1" class="data row0 col1" >512.1318</td>
# ...

# %%
hierarchicalModel = create_model('hclust', num_clusters=4)
hierarchicalModelPrediction = assign_model(hierarchicalModel)
hierarchicalModelPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_e0884" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0884_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e0884_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e0884_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e0884_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e0884_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e0884_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0884_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0884_row0_col0" class="data row0 col0" >0.5865</td>
#       <td id="T_e0884_row0_col1" class="data row0 col1" >512.1318</td>
# ...

# %%
evaluate_model(hierarchicalModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

iris_dataset = get_data('iris', verbose=False)
setup(data = iris_dataset, verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_90468" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90468_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_90468_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_90468_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_90468_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_90468_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_90468_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90468_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90468_row0_col0" class="data row0 col0" >0.6216</td>
#       <td id="T_90468_row0_col1" class="data row0 col1" >568.5478</td>
# ...

# %% [markdown]
# # Normalization

# %%
#Model Performance using "Normalization"
#Elbow Plot
setup(data = iris_dataset, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')

#Evaluation parameters for Cluster = 3, 4, 5, 6
setup(data = iris_dataset, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_17ed2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17ed2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_17ed2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_17ed2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_17ed2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_17ed2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_17ed2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17ed2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_17ed2_row0_col0" class="data row0 col0" >0.5667</td>
#       <td id="T_17ed2_row0_col1" class="data row0 col1" >320.0156</td>
# ...

# %% [markdown]
# # Transformation

# %%
# Model Performance using "Transformation"
#Elbow Plot
setup(data = iris_dataset, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')

# Evaluation parameters for Cluster = 3, 4, 5, 6
setup(data = iris_dataset, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5e99a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e99a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5e99a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5e99a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5e99a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5e99a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5e99a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e99a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e99a_row0_col0" class="data row0 col0" >0.5893</td>
#       <td id="T_5e99a_row0_col1" class="data row0 col1" >1225.1018</td>
# ...

# %% [markdown]
# # PCA

# %%
#Elbow Plot
setup(data = iris_dataset, pca = True, pca_method = 'linear', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')

#Evaluation parameters for Cluster = 3, 4, 5, 6
setup(data = iris_dataset, pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9a6cf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a6cf_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9a6cf_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9a6cf_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9a6cf_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9a6cf_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9a6cf_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a6cf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a6cf_row0_col0" class="data row0 col0" >0.5865</td>
#       <td id="T_9a6cf_row0_col1" class="data row0 col1" >512.1318</td>
# ...

# %% [markdown]
# # Transformation" + "Normalization

# %%
#Model Performance using "Transformation" + "Normalization"
#Elbow Plot
setup(data = iris_dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')

setup(data = iris_dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_21317" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21317_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_21317_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_21317_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_21317_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_21317_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_21317_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21317_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21317_row0_col0" class="data row0 col0" >0.5786</td>
#       <td id="T_21317_row0_col1" class="data row0 col1" >326.7618</td>
# ...

# %% [markdown]
# # "Transformation" + "Normalization" + "PCA"

# %%
# Model Performance using "Transformation" + "Normalization" + "PCA"
#Elbow Plot

setup(data = iris_dataset, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

x = create_model('hclust')
plot_model(x, plot = 'elbow')

setup(data = iris_dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
y = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
z = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
w = create_model('hclust', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_88ee4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88ee4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_88ee4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_88ee4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_88ee4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_88ee4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_88ee4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88ee4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_88ee4_row0_col0" class="data row0 col0" >0.5786</td>
#       <td id="T_88ee4_row0_col1" class="data row0 col1" >326.7618</td>
# ...

# %% [markdown]
# # Mean shift clustering              'meanshift'

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

iris_dataset = get_data('iris', verbose=False)
setup(data = iris_dataset, verbose=False)

x = create_model('dbscan')
# plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_aaca6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aaca6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_aaca6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_aaca6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_aaca6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_aaca6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_aaca6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aaca6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aaca6_row0_col0" class="data row0 col0" >0.5228</td>
#       <td id="T_aaca6_row0_col1" class="data row0 col1" >220.1813</td>
# ...

# %%
print("For Cluster = 3")
x = create_model('dbscan', num_clusters = 3)

print("For Cluster = 4")
x = create_model('dbscan', num_clusters = 4)

print("For Cluster = 5")
x = create_model('dbscan', num_clusters = 5)

print("For Cluster = 6")
x = create_model('dbscan', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_e51ea" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e51ea_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e51ea_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e51ea_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e51ea_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e51ea_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e51ea_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e51ea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e51ea_row0_col0" class="data row0 col0" >0.5228</td>
#       <td id="T_e51ea_row0_col1" class="data row0 col1" >220.1813</td>
# ...

# %%
#Model Performance using "Normalization"
#Elbow Plot
setup(data = iris_dataset, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('dbscan')
# plot_model(x, plot = 'elbow')

#Evaluation parameters for Cluster = 3, 4, 5, 6
setup(data = iris_dataset, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x = create_model('dbscan', num_clusters = 3)

print("For Cluster = 4")
x = create_model('dbscan', num_clusters = 4)

print("For Cluster = 5")
x = create_model('dbscan', num_clusters = 5)

print("For Cluster = 6")
x = create_model('dbscan', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f7775" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7775_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f7775_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f7775_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f7775_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f7775_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f7775_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7775_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f7775_row0_col0" class="data row0 col0" >0.2813</td>
#       <td id="T_f7775_row0_col1" class="data row0 col1" >65.1038</td>
# ...

# %%
# Model Performance using "Transformation"
#Elbow Plot
setup(data = iris_dataset, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
x = create_model('dbscan')
# plot_model(x, plot = 'elbow')

# Evaluation parameters for Cluster = 3, 4, 5, 6
setup(data = iris_dataset, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('dbscan', num_clusters = 3)

print("For Cluster = 4")
x = create_model('dbscan', num_clusters = 4)

print("For Cluster = 5")
x = create_model('dbscan', num_clusters = 5)

print("For Cluster = 6")
x = create_model('dbscan', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b5396" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5396_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b5396_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b5396_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b5396_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b5396_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b5396_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5396_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b5396_row0_col0" class="data row0 col0" >0.7594</td>
#       <td id="T_b5396_row0_col1" class="data row0 col1" >740.9297</td>
# ...

# %%
#PCA
#Elbow Plot
setup(data = iris_dataset, pca = True, pca_method = 'linear', verbose=False)
x = create_model('dbscan')
# plot_model(x, plot = 'elbow')

#Evaluation parameters for Cluster = 3, 4, 5, 6
setup(data = iris_dataset, pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('dbscan', num_clusters = 3)

print("For Cluster = 4")
x = create_model('dbscan', num_clusters = 4)

print("For Cluster = 5")
x = create_model('dbscan', num_clusters = 5)

print("For Cluster = 6")
x = create_model('dbscan', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_45c13" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45c13_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_45c13_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_45c13_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_45c13_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_45c13_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_45c13_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45c13_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_45c13_row0_col0" class="data row0 col0" >0.5228</td>
#       <td id="T_45c13_row0_col1" class="data row0 col1" >220.1813</td>
# ...

# %%
#Model Performance using "Transformation" + "Normalization"
#Elbow Plot
setup(data = iris_dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
x = create_model('dbscan')


setup(data = iris_dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('dbscan', num_clusters = 3)

print("For Cluster = 4")
x = create_model('dbscan', num_clusters = 4)

print("For Cluster = 5")
x = create_model('dbscan', num_clusters = 5)

print("For Cluster = 6")
x = create_model('dbscan', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_50c5a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50c5a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_50c5a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_50c5a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_50c5a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_50c5a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_50c5a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50c5a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_50c5a_row0_col0" class="data row0 col0" >0.2859</td>
#       <td id="T_50c5a_row0_col1" class="data row0 col1" >72.6619</td>
# ...

# %%
# Model Performance using "Transformation" + "Normalization" + "PCA"
#Elbow Plot

setup(data = iris_dataset, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

x = create_model('dbscan')
# plot_model(x, plot = 'elbow')

setup(data = iris_dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('dbscan', num_clusters = 3)

print("For Cluster = 4")
y = create_model('dbscan', num_clusters = 4)

print("For Cluster = 5")
z = create_model('dbscan', num_clusters = 5)

print("For Cluster = 6")
w = create_model('dbscan', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5e410" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e410_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5e410_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5e410_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5e410_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5e410_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5e410_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e410_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e410_row0_col0" class="data row0 col0" >0.2859</td>
#       <td id="T_5e410_row0_col1" class="data row0 col1" >72.6619</td>
# ...
